# %%
import os
import pandas as pd
import json
import folium
import numpy as np
import matplotlib.pyplot as plt
import branca.colormap as cm
# %matplotlib inline

# %%
"""EUROPE DATA FROM 'http://appsso.eurostat.ec.europa.eu/nui/submitViewTableAction.do"""

eu_data_path = 'data/chomage_europe.csv'
swiss_data_path = 'data/chomage_suisse.csv'
swiss_foreign_path = 'data/chomage_suisse_etrangere.csv'
swiss_ages_path = 'data/chomage_suisse_age.csv'

eu_topo_path = 'topojson/europe.topojson.json'
swiss_topo_path = 'topojson/ch-cantons.topojson.json'

eu_topo_data = json.load(open(eu_topo_path))
swiss_topo_data = json.load(open(swiss_topo_path))

# %% [markdown]
# # Question 1
#
# The data that we collected doesn't have all rates of all countries from europe. But at least it contains Switzerland's rate in order to be able to compare. You can click on the link above if you are curious!. Since we also have to find a way to show these countries are not present in the data on the map, we decided to assign value 0 to their rate.

# %%
def parse_eu_data(eu_data_path):
    df = pd.read_csv(eu_data_path)
    df = df[(df.ISCED11 == "All ISCED 2011 levels ") & (df.SEX == 'Total')]
    """Insert ID column using data from europe.topojson.json"""
    """For those countries that we don't have data (umployment rates), we put 0 for the rate"""
    names = df.GEO.tolist()
    countries = eu_topo_data['objects']['europe']['geometries']
    ids = []
    ids_no_data = []
    rates = []
    c = []
    c_no_data = []
    for country in countries:
        name = country['properties']['NAME']

        if name in names:
            c.append(name)
            ids.append(country['id'])
            rates.append(df.loc[df['GEO'] == name]['Value'].values[0])
        else:
            c_no_data.append(name)
            ids_no_data.append(country['id'])
    """Order is important because we take Rate and concatenate"""
    ids += ids_no_data         
    rates += [0]*(len(ids_no_data))
    c += c_no_data
    df = pd.DataFrame({
                        'Code' : ids,
                        'Rate' : rates,
                        'Country' : c
                     }) 
    df.Rate = df.Rate.astype(float)
    return df

# %%
df_eu = parse_eu_data(eu_data_path)
df_eu
# Out:
#    Code                                    Country  Rate
# 0    BG                                   Bulgaria   7.6
# 1    CY                                     Cyprus  13.0
# 2    DK                                    Denmark   6.2
# 3    IE                                    Ireland   7.9
# 4    EE                                    Estonia   6.8
# 5    AT                                    Austria   6.0
# 6    CZ                             Czech Republic   4.0
# 7    FI                                    Finland   8.8
# 8    FR                                     France  10.1
# 9    DE                                    Germany   4.1
# 10   GR                                     Greece  23.6
# 11   HR                                    Croatia  13.1
# 12   HU                                    Hungary   5.1
# 13   IS                                    Iceland   3.0
# 14   IT                                      Italy  11.7
# 15   LV                                     Latvia   9.6
# 16   LT                                  Lithuania   7.9
# 17   SK                                   Slovakia   9.7
# 18   MK  The former Yugoslav Republic of Macedonia  23.7
# 19   MT                                      Malta   4.7
# 20   BE                                    Belgium   7.8
# 21   LU                                 Luxembourg   6.3
# 22   NL                                Netherlands   6.0
# 23   NO                                     Norway   4.7
# 24   PL                                     Poland   6.2
# 25   PT                                   Portugal  11.2
# 26   RO                                    Romania   5.9
# 27   SI                                   Slovenia   8.0
# 28   ES                                      Spain  19.6
# 29   SE                                     Sweden   7.0
# 30   CH                                Switzerland   5.0
# 31   TR                                     Turkey  10.9
# 32   GB                             United Kingdom   4.8
# 33   AZ                                 Azerbaijan   0.0
# 34   AL                                    Albania   0.0
# 35   AM                                    Armenia   0.0
# 36   BA                     Bosnia and Herzegovina   0.0
# 37   GE                                    Georgia   0.0
# 38   IL                                     Israel   0.0
# 39   BY                                    Belarus   0.0
# 40   LI                              Liechtenstein   0.0
# 41   FO                              Faroe Islands   0.0
# 42   AD                                    Andorra   0.0
# 43   MC                                     Monaco   0.0
# 44   ME                                 Montenegro   0.0
# 45   MD                        Republic of Moldova   0.0
# 46   UA                                    Ukraine   0.0
# 47   SM                                 San Marino   0.0
# 48   RS                                     Serbia   0.0
# 49   VA                    Holy See (Vatican City)   0.0
# 50   RU                                     Russia   0.0

# %%
plt.boxplot(df_eu[df_eu.Rate > 0].Rate, 0, 'gD')
plt.show()

# %% [markdown]
# First, we decide to map gray color to those countries that we don't have data. Then as we saw here, there were two countries in which unemployement rate is an extreme case (nearly outliers), so we put these two countries into a special class... After, since we have to classifier for more than 30 countries, we decide to split these countries into 5 classes... In total, on out map we have 6 class:
# * Countries that we do not know their rate
# * Countries that unemployment rate is smaller than the first quartile
# * Countries that unemployment rate is bigger than the first quartile but smaller than the median (second quartile)
# * Countries that unemployment rate is bigger than the median but smaller than the third quartile
# * Countries that unemployment rate is bigger than the third quartile but smaller than 15%
# * Countries that unemployment rate is bigger than the 15%

# %%
[first_quartile, median, third_quartile] = np.percentile(df_eu[df_eu.Rate > 0].Rate, [25, 50, 75])
thresholds_eu = [min(df_eu[df_eu.Rate > 0].Rate), first_quartile , median, third_quartile, 15, max(df_eu.Rate)]
"5-class YlOrRd"
colors_mapping = ['#ffffb2', '#fecc5c','#fd8d3c', '#f03b20', '#bd0026'] 

colormap_eu = cm.StepColormap(colors_mapping, 
                              vmin=min(df_eu[df_eu.Rate > 0].Rate), vmax=max(df_eu.Rate), 
                              index=thresholds_eu,
                              caption='Unemployment rates of Europe in 2016')
colormap_eu
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="51" ...

# %%
def eu_style_func(code):
    rate = df_eu.loc[df_eu['Code'] == code]['Rate'].values[0]
    if (rate == 0) : 
        return 'gray'
    else : 
        return colormap_eu(rate)

# %%
eu_map = folium.Map(location=[45,10], zoom_start=5, tiles='cartodbpositron')
folium.TopoJson(
    eu_topo_data,
    'objects.europe',
    style_function=lambda feature: {
        'fillColor' : eu_style_func(feature['id']),
        'color' : 'black',
        'weight' : 1,
        'fillOpacity' : 1,
        'dashArray' : '1, 1'
        }
    ).add_to(eu_map)
eu_map.add_child(colormap_eu)
eu_map.save('eu_map.html')
eu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Switzerland is on the first zone among europe, which means the economy of Switzerland is stable and the jobs don't scarce.

# %% [markdown]
# # Question 2

# %% [markdown]
# We collected data from Switzerland at September 2017 (at a recent date). Moreover, the fact of data collected in 2016 or September 2017 is not important for a Visualization project. The important things are how to define threshold and color mapping on the map.

# %%
df_suisse = pd.read_csv(swiss_data_path, usecols=[0,1,2,3,4])
df_suisse
# Out:
#    Canton  Taux de chomage  Chomeurs inscrits  Demandeurs demploi  \
# 0      ZH              3.3              27225               34156
# 1      BE              2.4              13658               18385
# 2      LU              1.7               3885                6756
# 3      UR              0.6                112                 257
# 4      SZ              1.7               1455                2229
# 5      OW              0.7                153                 319
# 6      NW              1.0                248                 436
# 7      GL              1.8                416                 713
# 8      ZG              2.3               1543                2615
# 9      FR              2.7               4466                7837
# 10     SO              2.6               3801                6628
# 11     BS              3.5               3455                5168
# 12     BL              2.8               4082                5540
# 13     SH              3.0               1286                2328
# 14     AR              1.7                523                 866
# 15     AI              0.7                 62                 102
# 16     SG              2.2               6127               10363
# 17     GR              1.1               1166                2590
# 18     AG              2.9              10684               15145
# 19     TG              2.0               3058                5618
# 20     TI              3.1               5202                8675
# 21     VD              4.3              17155               24649
# 22     VS              2.8               4816                8027
# 23     NE              5.1               4738                6350
# 24     GE              5.2              12234               15497
# 25     JU              4.4               1619                2375
#
#     Demandeurs demploi non chomeurs
# 0                              6931
# 1                              4727
# 2                              2871
# 3                               145
# 4                               774
# 5                               166
# 6                               188
# 7                               297
# 8                              1072
# 9                              3371
# 10                             2827
# 11                             1713
# 12                             1458
# 13                             1042
# 14                              343
# 15                               40
# 16                             4236
# 17                             1424
# 18                             4461
# 19                             2560
# 20                             3473
# 21                             7494
# 22                             3211
# 23                             1612
# 24                             3263
# 25                              756

# %% [markdown]
# Now, let's say the unemployment rate defined by Swiss Confederation is RATE_A vs RATE_B (the
# unemployment rate in which we don't count in your statistics people who already have a job and are looking for a new one) => RATE_B is defined by the quotient of 'chomage_inscrits' and 'demandeurs demploi' then time with the 'taux de chomage'

# %%
RATE_A = df_suisse['Taux de chomage']
RATE_B = np.round(df_suisse['Chomeurs inscrits'] / df_suisse['Demandeurs demploi'] * df_suisse['Taux de chomage'], 1)

# %%
df_suisse = pd.DataFrame({
    'CODE' : df_suisse['Canton'],
    'RATE_A' : RATE_A,
    'RATE_B' : RATE_B
})
df_suisse
# Out:
#    CODE  RATE_A  RATE_B
# 0    ZH     3.3     2.6
# 1    BE     2.4     1.8
# 2    LU     1.7     1.0
# 3    UR     0.6     0.3
# 4    SZ     1.7     1.1
# 5    OW     0.7     0.3
# 6    NW     1.0     0.6
# 7    GL     1.8     1.1
# 8    ZG     2.3     1.4
# 9    FR     2.7     1.5
# 10   SO     2.6     1.5
# 11   BS     3.5     2.3
# 12   BL     2.8     2.1
# 13   SH     3.0     1.7
# 14   AR     1.7     1.0
# 15   AI     0.7     0.4
# 16   SG     2.2     1.3
# 17   GR     1.1     0.5
# 18   AG     2.9     2.0
# 19   TG     2.0     1.1
# 20   TI     3.1     1.9
# 21   VD     4.3     3.0
# 22   VS     2.8     1.7
# 23   NE     5.1     3.8
# 24   GE     5.2     4.1
# 25   JU     4.4     3.0

# %%
df_suisse.plot(kind='box', figsize=(7,7))

# %% [markdown]
# Switzerland :
# * RATE_A : the mean is about 2.5% and the max rate is about 5.2% which is quite near the 'limit horizontal bar. The different is not high so we decided divide the threshold into 4 classes by quartile method.
# * RATE_B : the mean is about 1.7% and the max rate is about 4.1% which is now far from the 'limit horizontal bar'. And it's the different, let's assign these two cantons into a class and divide the other cantons into 4 classes by quartile method.

# %% [markdown]
# ### RATE_A: rate defined by Swiss Confederation

# %%
print('Unemployment mean of RATE_A:',np.mean(df_suisse.RATE_A))
# Out:
# Unemployment mean of RATE_A: 2.5230769230769234

# %%
colors_A = ['#ffffb2','#fecc5c','#fd8d3c','#e31a1c']

[first_quartile_A, median_A, third_quartile_A] = np.percentile(df_suisse.RATE_A, [25, 50, 75])
thresholds_suisse_A = [min(df_suisse.RATE_A), first_quartile_A, median_A, third_quartile_A, max(df_suisse.RATE_A)]

colormap_suisse_A = cm.StepColormap(colors_A, 
                                  vmin = min(df_suisse.RATE_A), vmax = max(df_suisse.RATE_A), 
                                  index = thresholds_suisse_A,
                                  caption='Unemployment rates in Switzerland in September 2017')
colormap_suisse_A
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="51" ...

# %%
suisse_map_A = folium.Map(location=[46.9,8], zoom_start=8, tiles='cartodbpositron')
folium.TopoJson(
    swiss_topo_data,
    'objects.cantons',
    style_function=lambda feature: {
        'fillColor': colormap_suisse_A(df_suisse.loc[df_suisse['CODE'] == feature['id']]['RATE_A'].values[0]),
        'color' : 'black',
        'fillOpacity' : 1,
        'weight' : 1,
        'dashArray' : '1, 1'
        }
    ).add_to(suisse_map_A)
suisse_map_A.add_child(colormap_suisse_A)
suisse_map_A.save('suisse_map_A.html')
suisse_map_A
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * Canton that has a big city/hub (Geneva, Lausanne, Zurich..) tends to have a higher unemployment rate.

# %% [markdown]
# ## RATE_B: don't count people who already have a job and are looking for a new one

# %%
print('Unemployment mean of RATE_B:',np.mean(df_suisse.RATE_B))
# Out:
# Unemployment mean of RATE_B: 1.6576923076923078

# %%
colors_B = ['#ffffb2','#fecc5c','#fd8d3c','#f03b20', '#bd0026']
[first_quartile_B, median_B, third_quartile_B] = np.percentile(df_suisse.loc[df_suisse['RATE_B'] < 3.5].RATE_B, [25, 50, 75])
thresholds_suisse_B = [min(df_suisse.RATE_B), first_quartile_B, median_B, third_quartile_B, 3.5 , max(df_suisse.RATE_B)]

colormap_suisse_B = cm.StepColormap(colors_B, 
                                  vmin = min(df_suisse.RATE_B), vmax = max(df_suisse.RATE_B), 
                                  index = thresholds_suisse_B,
                                  caption='Unemployment rates w/o counting people who already have a job in Switzerland in September 2017')
colormap_suisse_B
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="51" ...

# %%
suisse_map_B = folium.Map(location=[46.9,8], zoom_start=8, tiles='cartodbpositron')
folium.TopoJson(
    swiss_topo_data,
    'objects.cantons',
    style_function=lambda feature: {
        'fillColor': colormap_suisse_B(df_suisse.loc[df_suisse['CODE'] == feature['id']]['RATE_B'].values[0]),
        'color' : 'black',
        'fillOpacity' : 1,
        'weight' : 1,
        'dashArray' : '1, 1'
        }
    ).add_to(suisse_map_B)
suisse_map_B.add_child(colormap_suisse_B)
suisse_map_B.save('suisse_map_B.html')
suisse_map_B
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Question 3
#
# ### Different between Swiss rate and Foreign rate

# %%
df = pd.read_csv(swiss_foreign_path, usecols=[0,1,2])
df_Swiss   = df[df['Nationalite']=='Suisses']
df_Foreign = df[df['Nationalite']=='Etrangers']

# %%
df = pd.DataFrame({
    'CODE' : [c for c in df_Swiss.CODE],
    'SWISS_RATE' : [r for r in df_Swiss.RATE],
    'FOREIGN_RATE' : [r for r in df_Foreign.RATE]
})
df['RATIO'] = np.round(df.FOREIGN_RATE / df.SWISS_RATE, 1)
df
# Out:
#    CODE  FOREIGN_RATE  SWISS_RATE  RATIO
# 0    ZH           5.3         2.5    2.1
# 1    BE           5.5         1.8    3.1
# 2    LU           3.9         1.3    3.0
# 3    UR           2.1         0.4    5.2
# 4    SZ           3.4         1.2    2.8
# 5    OW           2.2         0.5    4.4
# 6    NW           2.9         0.7    4.1
# 7    GL           3.4         1.4    2.4
# 8    ZG           3.9         1.7    2.3
# 9    FR           5.0         2.0    2.5
# 10   SO           5.0         1.9    2.6
# 11   BS           4.6         2.8    1.6
# 12   BL           4.8         2.2    2.2
# 13   SH           5.1         2.2    2.3
# 14   AR           3.4         1.4    2.4
# 15   AI           2.0         0.5    4.0
# 16   SG           4.3         1.5    2.9
# 17   GR           2.3         0.7    3.3
# 18   AG           5.6         2.1    2.7
# 19   TG           3.9         1.4    2.8
# 20   TI           4.6         2.5    1.8
# 21   VD           5.9         3.5    1.7
# 22   VS           4.9         2.1    2.3
# 23   NE           7.4         4.2    1.8
# 24   GE           5.7         4.8    1.2
# 25   JU           9.0         3.6    2.5

# %%
#plt.plot(df.RATIO, np.zeros_like(df.RATIO), 'o')

# %%
print('Unemployment rate in Switzerland of Swiss', np.mean(df.SWISS_RATE))
print('Unemployment rate in Switzerland of Foreign', np.mean(df.FOREIGN_RATE))
# Out:
# Unemployment rate in Switzerland of Swiss 1.9576923076923076
# Unemployment rate in Switzerland of Foreign 4.4653846153846155

# %%
df.plot(figsize=(7,7), kind='box')

# %% [markdown]
# Since the ratio is a kind of special: ratio = 1 means the foreign rate equals to the swiss rate while ratio = 2 means the foreign rate is 2 times higher than the swiss rate ... This time, instead of using the quartile method we would like devide the threshold in interval of [min,2], [2,3], [3,4], [4, max]

# %%
thresholds_suisse_C = [min(df.RATIO), 2.1, 3, 4, max(df.RATIO)]
colors_C = ['#ffffb2','#fecc5c','#fd8d3c','#e31a1c']
colormap_suisse_C = cm.StepColormap(colors_C, 
                                  vmin = min(df.RATIO), vmax = max(df.RATIO), 
                                  index = thresholds_suisse_C,
                                  caption='Ratio of unemployment rates of Foreign vs Swiss in Switzerland 09/2017')
colormap_suisse_C
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="51" ...

# %%
suisse_map_C = folium.Map(location=[46.9,8], zoom_start=8, tiles='cartodbpositron')
folium.TopoJson(
    swiss_topo_data,
    'objects.cantons',
    style_function=lambda feature: {
        'fillColor': colormap_suisse_C(df.loc[df['CODE'] == feature['id']]['RATIO'].values[0]),
        'color' : 'black',
        'fillOpacity' : 1,
        'weight' : 1,
        'dashArray' : '3, 3'
        }
    ).add_to(suisse_map_C)
suisse_map_C.add_child(colormap_suisse_C)
suisse_map_C.save('suisse_map_C.html')
suisse_map_C
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# [Percentage of foreigner per canton in Switzerland](https://www.travailler-en-suisse.ch/classement-cantons-suisses-immigration-etrangers-16-06-2011.html)
#
# * First of all, we saw that the darkness of the color has a correlation with the percentage of foreigners in Switzerland. Precisely, the percentage of foreigners of cantons in red is small (UR - 9.5%, OW - 13.3%, NW - 11.3%) vs the one of cantons in yellow is big (GE - 36%, VD - 31%, TI - 26%)
#
# * One of hypothesis that we can make is: does foreign workers take the job of swiss people and it leads to the reduction of the ratio of the unemployment rates between foreign and swiss?
#
# * Secondly, we also saw that the darkness of the color has somehow a correlation with the population. Precisely, the population in these cantons (Red: UR, OW, NW. Orange: GR, AI) is very small while population in VD, GE, TI (yellow) is bigger.
#
# * An onother hypothesis can also be made is: is it more difficult for the foreigners for looking a job if they live in a canton that population is not high? Then it leads to the fact that foreigners have to move to the big city/hub (VD, GE, ZH) ???
#
# * It seems that the most of cantons in switzerland have a ratio between [2,3] which means the ratio of the unemployment rate of foreigners is about 2 or 3 times higher than the one of swiss citizenship.

# %% [markdown]
# ### Differences between age groups

# %%
df_age = pd.read_csv(swiss_ages_path, usecols=[0,2,3])
df_age_one   = df_age[df_age['Mesures']=='15-24 ans']
df_age_two   = df_age[df_age['Mesures']=='25-49 ans']
df_age_three = df_age[df_age['Mesures']=='50 ans et plus']

df_age_one.head()
# Out:
#      Canton    Mesures  Taux de chomage
# 0    Zurich  15-24 ans              3.7
# 3     Berne  15-24 ans              2.8
# 6   Lucerne  15-24 ans              2.1
# 9       Uri  15-24 ans              0.5
# 12   Schwyz  15-24 ans              1.6

# %%
#df_age_one  .drop('Mesures', axis=1)
#df_age_two  .drop('Mesures', axis=1)
#df_age_three.drop('Mesures', axis=1)
#df_age_one  .set_index('Canton')
#df_age_two  .set_index('Canton')
#df_age_three.set_index('Canton')

#df_age_one  .plot.barh(stacked=True, figsize=(12,8), title='Unemployment rates in Switzerland in September 2017 with age from [15-24]')
#df_age_two  .plot.barh(stacked=True, figsize=(12,8), title='Unemployment rates in Switzerland in September 2017 with age from [25-49]')
#df_age_three.plot.barh(stacked=True, figsize=(12,8), title='Unemployment rates in Switzerland in September 2017 with age from [50-  ]')

# %%
df = pd.DataFrame({
    'Canton' : [c for c in df_age_one.Canton],
    '15-24 ans' : [r for r in df_age_one['Taux de chomage']],
    '25-49 ans' : [r for r in df_age_two['Taux de chomage']],
    '50 ans et plus' : [r for r in df_age_three['Taux de chomage']],
})
df = df.set_index('Canton')

# %%
df.plot.barh(stacked=True, figsize=(10,15), title='Unemployment rates in Switzerland in September 2017')
